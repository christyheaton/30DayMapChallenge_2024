# %%
import geopandas as gpd
import folium

# %%
filename = "blue_orange_trees_SDOT.geojson"
file = open(filename)
blue_orange_trees = gpd.read_file(file)

# %%
blue_orange_trees["COMMON_NAME"].value_counts()
# Out:
# COMMON_NAME
# Orangebark Stewartia    111
# Colorado Blue Spruce     48
# Osage Orange             40
# Blue blossom             13
# Mock Orange               5
# Blue Lawson Cypress       5
# Name: count, dtype: int64

# %%
blue_orange_trees = blue_orange_trees[["COMMON_NAME", "geometry"]]

# %%
blue_orange_trees["COLOR"] = blue_orange_trees["COMMON_NAME"].apply(
    lambda x: "blue" if "blue" in str(x).lower() else ("orange" if "orange" in str(x).lower() else None)
)

# %%
blue_orange_trees.explore(
    color="COLOR",
    cmap={"blue": "blue", "orange": "orange"},
    tooltip=["COMMON_NAME"],
    style_kwds= {"stroke": False},
    marker_kwds= {"radius": 4},
    tiles = "CartoDB positron"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e88ed72f0a4ceaa087a45b8f73a5e6e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e88ed72f0a4ceaa087a45b8f73a5e6e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e88ed72f0a4ceaa087a45b8f73a5e6e3 = L.map(
#                 &quot;map_e88ed72f0a4ceaa087a45b8f73a5e6e3&quot;,
#                 {
#                     center: [47.60567048100006, -122.33162957699994],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e88ed72f0a4ceaa087a45b8f73a5e6e3);
#
#
#
#
#
#             var tile_layer_4196705f182fd848b2503e1f1f7c528b = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4196705f182fd848b2503e1f1f7c528b.addTo(map_e88ed72f0a4ceaa087a45b8f73a5e6e3);
#
#             map_e88ed72f0a4ceaa087a45b8f73a5e6e3.fitBounds(
#                 [[47.49966193400007, -122.41650429899994], [47.71167902800005, -122.24675485499995]],
#                 {}
#             );
#
#
#         function geo_json_0f8cd10fcb4983c4be133fdc899c6641_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;71&quot;: case &quot;78&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;98&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;119&quot;: case &quot;120&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;123&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;126&quot;: case &quot;127&quot;: case &quot;128&quot;: case &quot;129&quot;: case &quot;130&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;134&quot;: case &quot;135&quot;: case &quot;136&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;140&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;173&quot;: case &quot;175&quot;: case &quot;176&quot;: case &quot;177&quot;: case &quot;181&quot;: case &quot;182&quot;: case &quot;183&quot;: case &quot;186&quot;: case &quot;188&quot;: case &quot;189&quot;: case &quot;192&quot;: case &quot;194&quot;: case &quot;195&quot;: case &quot;196&quot;: case &quot;203&quot;: case

# %%
m = folium.Map(location=[blue_orange_trees.geometry.y.mean(), blue_orange_trees.geometry.x.mean()],
               zoom_start=11, tiles="CartoDB positron")

for idx, row in blue_orange_trees.iterrows():
    color = row["COLOR"]
    icon_html = f"""<span class="fa fa-tree" style="color:{color}; font-size:14px"></span>"""
    icon = folium.DivIcon(html=f'<div style="text-align:center">{icon_html}</div>')
    lat, lon = row.geometry.y, row.geometry.x
    folium.Marker(location=[lat, lon], icon=icon, 
                  tooltip=row["COMMON_NAME"]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22fc12eea0ee347c8b136589e6f1ad26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22fc12eea0ee347c8b136589e6f1ad26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22fc12eea0ee347c8b136589e6f1ad26 = L.map(
#                 &quot;map_22fc12eea0ee347c8b136589e6f1ad26&quot;,
#                 {
#                     center: [47.61805207489194, -122.345700558536],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bd0f70a8d8370ce5aed46189684fce8 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3bd0f70a8d8370ce5aed46189684fce8.addTo(map_22fc12eea0ee347c8b136589e6f1ad26);
#
#             var marker_edd67417a5dd3e6dbbcf9539cbed0d13 = L.marker(
#                 [47.698393347000035, -122.37921889299997],
#                 {}
#             ).addTo(map_22fc12eea0ee347c8b136589e6f1ad26);
#
#
#             var div_icon_9cea7b7ec392eb19392f9c1b8b98d6d2 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align:center\&quot;\u003e\u003cspan class=\&quot;fa fa-tree\&quot; style=\&quot;color:orange; font-size:14px\&quot;\u003e\u003c/span\u003e\u003c/div\u003e&quot;});
#             marker_edd67417a5dd3e6dbbcf9539cbed0d13.setIcon(div_icon_9cea7b7ec392eb19392f9c1b8b98d6d2);
#
#
#             marker_edd67417a5dd3e6dbbcf9539cbed0d13.bindTooltip(
#                 `&lt;div&gt;
#                      Orangebark Stewartia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3bad142336cb0db4fc1c02df7932a800 = L.marker(
#                 [47.62594341700003, -122.29523915199997],
#                 {}
#             ).addTo(map_22fc12eea0ee347c8b136589e6f1ad26);
#
#
#             var div_icon_ea9ed478b3040e505570b43891f4e1fc = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align:center\&quot;\u003e\u003cspan class=\&quot;fa fa-tree\&quot; style=\&quot;color:blue; font-size:14px\&quot;\u003e\u003c/span\u003e\u003c/div\u003e&quot;});
#             marker_3bad142336cb0db4fc1c02df7932a800.setIcon(div_icon_ea9ed478b3040e505570b43891f4e1fc);
#
#
#             marker_3bad142336cb0db4fc1c02df7932a800.bindTooltip(
#                 `&lt;div&gt;
#                      Colorado Blue Spruce
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_11fef09e99fa36d6dca39b7a95bfbbb6 = L.marker(
#                 [47.669151312000054, -122.33655314899994],
#                 {}
#             ).addTo(map_22fc12eea0ee347c8b136589e6f1ad26);
#
#
#             var div_icon_4eba4eda3fe4d746265689970e28789e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align:center\&quot;\u003e\u003cspan class=\&quot;fa fa-tree\&quot; style=\&quot;color:orange; font-size:14px\&quot;\u003e\u003c/span\u003e\u003c/div\u003e&quot;});
#             marker_11fef09e99fa36d6dca39b7a95bfbbb6.setIcon(div_icon_4eba4eda3fe4d746265689970e28789e);
#
#
#             marker_11fef09e99fa36d6dca39b7a95bfbbb6.bindTooltip(
#                 `&lt;div&gt;
#                      Mock Orange
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_99b2598412382730e7a28cdf46dabaf2 = L.marker(
#                 [47.668622302000074, -122.35635575999999],
#                 {}
#             ).addTo(map_22fc12eea0ee347c8b136589e6f1ad26);
#
#
#             var div_icon_f3b4f17277499f6cfef563035e17a433 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;text-align:center\&quot;\u003e\u003cspan class=\&quot;fa fa-tree\&quot; style=\&quot;color:orange; font-size:14px\&quot;\u003e\u003c/span\u003e\u003c/div\u003e&quot;});
#             marker_99b2598412382730e7a28cdf46dabaf2.setIcon(div_icon_f3b4f17277499f6cfef563035e17a433);
#
#
#             marker_99b2598412382730e7a28cdf46dabaf2.bindTooltip(
#                 `&lt;div&gt;
#                      Mock Orange
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dacb5676816ff078fe0f5bbd4097c083 = L.marker(
#                 [47.59193110800004, -122.28931045799999],
#                 {}
#             ).addTo(map_22fc12eea0ee347c8b136589e6f1ad26);

# %%
m.save("sdot_trees_2_colors.html")
